# %%
input_file = open("data.txt","r")
lines = input_file.readlines()[:-1]
lines[0].split(':')
names = list(map(lambda line: line.split(':')[0], lines))
stats = list(map(lambda strarr: list(map(float, strarr.split())) , list(map(lambda line: line.split(':')[1], lines))))
input_file.close()
import matplotlib.pyplot as plt
# %matplotlib inline
h = [None for id in range(len(stats))]
for id in range(len(stats)):
    h[id], = plt.plot(stats[id], label=names[id])
plt.legend(handles=h)
pt.
plt.xlabel('epochs')
plt.ylabel('accuracy')
plt.show()
